# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# This is for custom colormap
# https://matplotlib.org/tutorials/colors/colorbar_only.html
import matplotlib as mpl

from sklearn.model_selection import train_test_split
from sklearn import tree
from IPython.display import Image

# %%
# Dont worry about why I choose it
my_random_state = 13

# %% [markdown]
# ### Load Data

# %%
from sklearn.datasets import load_iris
data = load_iris()

df = pd.DataFrame(data.data, columns=data.feature_names)

# To simplify the decision tree, 
# I am restricting it to only one feature
df = df[['petal length (cm)']]

df['target'] = data.target

# %%
df.head(2)
# Out:
#    petal length (cm)  target
# 0                1.4       0
# 1                1.4       0

# %% [markdown]
# ### Split Data into Training and Test Sets

# %% [markdown]
# One of the benefits of Decision Trees is that you don't have to standardize your data unlike PCA and logistic regression which are [sensitive to effects of not standardizing your data](http://scikit-learn.org/stable/auto_examples/preprocessing/plot_scaling_importance.html#sphx-glr-auto-examples-preprocessing-plot-scaling-importance-py).

# %%
# test_size: what proportion of original data is used for test set
X_train, X_test, y_train, y_test = train_test_split(df['petal length (cm)'],df['target'],random_state=my_random_state)

# %% [markdown]
# ## Classification Tree

# %% [markdown]
# <b>Step 1</b>: Import the model you want to use

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# <b>Step 2</b>: Make an instance of the Model

# %%
clf = DecisionTreeClassifier(max_depth=1,
                             random_state=my_random_state)

# %% [markdown]
# <b>Step 3</b>: Training the model on the data, storing the information learned from the data

# %% [markdown]
# Model is learning the relationship between x (features sepal width, sepal height etc) and y (labels-which species of iris)

# %%
clf.fit(X_train.values.reshape(-1, 1), y_train )
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=13,
#             splitter='best')

# %% [markdown]
# <b>Step 4</b>: Predict the labels of new data (new images)

# %% [markdown]
# To predict a class of a new instance given its feature measurements using the decision tree, start at the root of the decision tree and take the decision at the each level based on the appropriate feature measurement until you get to the leaf node. The prediction is just the majority class of the instances in that leaf node.

# %% [markdown]
# Uses the information the model learned during the model training process

# %%
X_test.iloc[0]
# Out:
# 4.5

# %%
X_test.iloc[0:1].values
# Out:
# array([4.5])

# %%
X_test.iloc[0:1].values.reshape(-1,1)
# Out:
# array([[4.5]])

# %%
# Predict for 1 observation 
clf.predict(X_test.values.reshape(-1, 1)[0:1])
# Out:
# array([1])

# %% [markdown]
# Predict for Multiple Observations (images) at Once

# %%
clf.predict(X_test.values.reshape(-1, 1)[0:10])
# Out:
# array([1, 1, 0, 1, 1, 0, 1, 1, 0, 1])

# %% [markdown]
# ### Visualize Decision Tree

# %% [markdown]
# Dont run if you care about split point.

# %% [markdown]
# You can create a dot file easily with .export_graphviz. Converting it to png can be a hassle without [homebrew](https://hackernoon.com/how-to-install-and-use-homebrew-80eeb55f73e9) or conda. If you don't want to install graphviz, you can use an [online converter](http://webgraphviz.com).

# %%
tree.export_graphviz(clf,
                     out_file="../dotfiles/iris_depth2_decisionTree.dot",
                     feature_names=['petal length (cm)'],
                     class_names=data.target_names, 
                     filled = False)

# %%
# !dot -Tpng -Gdpi=300 dotfiles/iris_depth2_decisionTree.dot -o dotfiles/iris_depth2_decisionTree.png

# %% [markdown]
# ### Gini Criterion

# %%
# !dot -Tpng -Gdpi=300 dotfiles/iris_depth1_gini_decisionTree.dot -o dotfiles/iris_depth1_gini_decisionTree.png

# %%
Image(filename ="../dotfiles/iris_depth1_gini_decisionTree.png")

# %% [markdown]
# ### Entropy

# %%
# !dot -Tpng -Gdpi=300 dotfiles/iris_depth1_entropy_decisionTree.dot -o dotfiles/iris_depth1_entropy_decisionTree.png

# %%
#PATH = !pwd
Image(filename =  "../dotfiles/iris_depth1_entropy_decisionTree.png")

# %%
Image(filename =  "../dotfiles/iris_depth2_gini_decisionTree.png")

# %% [markdown]
# I edited the file to have text colors correspond to whether they are leaf/terminal nodes or decision nodes using nano (text editor). If you are interested, tou can look at the dot files to see how they differ from the typical output.

# %%
# !dot -Tpng -Gdpi=300 Graphviz_Dot_Examples/irisGreenLeafBlueDecisionDepth2.dot -o Graphviz_Dot_Examples/irisGreenLeafBlueDecisionDepth2.png

# %%
Image(filename ="../images/irisGreenLeafBlueDecisionDepth2.png")

# %%
Image(filename =  "../images/DT_brown_blue_green.png")

# %% [markdown]
# For the purpose of making something pretty for a blog, I made some adjustments to iris_depth2_decisionTreeExample.dot to have more emphasis on the arrows for an example. The final product is below.

# %%
Image(filename ="../images/exampleTreeDone.png")

# %% [markdown]
# ## Misclassification

# %%
X_train.head(1)
# Out:
# 68    4.5
# Name: petal length (cm), dtype: float64

# %%
trainData = pd.concat([X_train, pd.DataFrame(y_train)], axis = 1)

# %%
trainData['Nothing'] = 0

# %%
trainData.head(1)
# Out:
#     petal length (cm)  target  Nothing
# 68                4.5       1        0

# %% [markdown]
# ### petal length (cm) <= 2.45

# %%
decisionNode1 = trainData.copy()

# %%
indicesToKeep = (decisionNode1['target'] == 1)

decisionNode1.loc[indicesToKeep, 'target'] = 2

# %%
decisionNode1.target.value_counts(dropna = True)
# Out:
# 2    74
# 0    38
# Name: target, dtype: int64

# %%
fig = plt.figure(figsize = (8,3))

ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('')

for index, target, color in zip([0, 1,  2], ['Iris-setosa','Iris-versicolor','Iris-virginica'], ['r','lime','cyan']):
    indicesToKeep = trainData['target'] == index
    
    if index == 1: 
        z_order = 10
    if index == 2:
        z_order = 20
    if index == 0:
        z_order = 1

    ax.scatter(trainData.loc[indicesToKeep, 'petal length (cm)']
               , trainData.loc[indicesToKeep, 'Nothing']
               , c = color
               , s = 120
               , zorder = z_order
               , edgecolors = 'k'
               , linewidth = 1.5)
    
ax.legend(['Iris-setosa','Iris-versicolor','Iris-virginica'], markerscale = .95)    

minimum = trainData.loc[:, 'petal length (cm)'].min() - .5  
maximum = trainData.loc[:, 'petal length (cm)'].max() + .5 

ax.set_ylim(-0.01,0.01)
ax.set_xlim(minimum,maximum)
xlist = np.linspace(minimum, maximum, 100)

# ylist could be anything in this case
ylist = np.linspace(-3.0, 3.0, 100)
xx, yy = np.meshgrid(xlist, ylist)

# Making an array of the same shape as input 
# This is an array to mimic a decision boundary 
Z = xx.copy()

# https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html
# my decision boundary 
def boundary(array):
    if array <= 2.45:
        return(0)
    if array > 2.45:
        return(2)
    else:
        return()

vfunc = np.vectorize(boundary)
Z = vfunc(Z)

# Put the result into a color plot 
n_classes = 2 

custom_map = mpl.colors.ListedColormap(['red', 'lime'])

contours = plt.contourf(xx, yy, Z, alpha=0.3,
                       cmap=custom_map,
                       zorder=1)

ax.axvline(x = 2.45, c = 'k')
ax.set_yticks([])
ax.set_yticklabels([])
#ax.set_xlabel('petal length (cm)', fontsize = 14)
ax.set_title('Is the petal length (cm) <= 2.45', fontsize = 17)

plt.gcf().subplots_adjust(bottom=0.20)
plt.savefig('../images/notperfectClassDN1.png', dpi = 800)

# %% [markdown]
# ### petal length (cm) <= 4.95

# %%
indicesToKeep = (trainData['target'] == 1) | (trainData['target'] == 2)

minimum = trainData.loc[indicesToKeep, 'petal length (cm)'].min() - .1  
maximum = trainData.loc[indicesToKeep, 'petal length (cm)'].max() + .1 
xlist = np.linspace(minimum, maximum, 100)

# ylist could be anything in this case
ylist = np.linspace(-3.0, 3.0, 100)
xx, yy = np.meshgrid(xlist, ylist)

# %%
fig = plt.figure(figsize = (8,3))

ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('')
targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'lime', 'cyan']
ax.set_ylim(-0.01,0.01)
for index,(target, color) in enumerate(zip(targets,colors)):
    indicesToKeep = trainData['target'] == index
    
    if index == 1: 
        z_order = 10
    if index == 2:
        z_order = 20
    if index == 0:
        z_order = 10
        continue
    ax.scatter(trainData.loc[indicesToKeep, 'petal length (cm)']
               , trainData.loc[indicesToKeep, 'Nothing']
               , c = color
               , s = 120
               , zorder = z_order
               , edgecolors = 'k'
               , linewidth = 1.5)

ax.legend(['Iris-versicolor', 'Iris-virginica'], markerscale = .95)    

indicesToKeep = (trainData['target'] == 1) | (trainData['target'] == 2)

minimum = trainData.loc[indicesToKeep, 'petal length (cm)'].min() - .1  
maximum = trainData.loc[indicesToKeep, 'petal length (cm)'].max() + .1 
xlist = np.linspace(minimum, maximum, 100)

# ylist could be anything in this case
ylist = np.linspace(-3.0, 3.0, 100)
xx, yy = np.meshgrid(xlist, ylist)


# Making an array of the same shape as input 
# This is an array to mimic a decision boundary 
Z = xx.copy()

# https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html
# my decision boundary 
def boundary(array):
    if array <= 4.95:
        return(1)
    if array > 4.95:
        return(2)
    else:
        return()

vfunc = np.vectorize(boundary)
Z = vfunc(Z)

# Put the result into a color plot 
n_classes = 2 

custom_map = mpl.colors.ListedColormap(['lime', 'cyan'])

contours = plt.contourf(xx, yy, Z, alpha=0.3,
                       cmap=custom_map,
                       zorder=1)

ax.axvline(x = 4.95, c = 'k')
ax.set_yticks([])
ax.set_yticklabels([])
#ax.set_xlabel('petal length (cm)', fontsize = 14)
ax.set_title('Is the petal length (cm) <= 4.95', fontsize = 17)
# plt.tight_layout()


ax.annotate('Misclassified', xy=(4.515,-0.0005), xytext=(4.1,-0.006), fontsize = 13,
            arrowprops={'arrowstyle': '->', 'color': 'black', 'lw': 2},
            va='center');

ax.annotate('', xy=(4.85,-0.0009), xytext=(4.5,-0.0048), fontsize = 13,
            arrowprops={'arrowstyle': '->', 'color': 'black', 'lw': 2},
            va='center');


plt.gcf().subplots_adjust(bottom=0.20)
plt.savefig('../images/notperfectClassDN2.png', dpi = 400)

# %% [markdown]
# ## Fake Splits to Show for Gini Calc (not used for figures in blog at the moment)
#
# ### petal length (cm) <= 3.6

# %% [markdown]
# This section can be combined with gini and entropy calculation to show that some splits obviously have better gini than others.

# %%
fig = plt.figure(figsize = (8,3))

ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('')

for index, target, color in zip([0, 1,  2], ['Iris-setosa','Iris-versicolor','Iris-virginica'], ['r','pink','cyan']):
    indicesToKeep = trainData['target'] == index
    
    if index == 1: 
        z_order = 10
    if index == 2:
        z_order = 20
    if index == 0:
        z_order = 1

    ax.scatter(trainData.loc[indicesToKeep, 'petal length (cm)']
               , trainData.loc[indicesToKeep, 'Nothing']
               , c = color
               , s = 120
               , zorder = z_order
               , edgecolors = 'k'
               , linewidth = 1.5)
    
ax.legend(['Iris-setosa','Iris-versicolor','Iris-virginica'], markerscale = .95)    

minimum = trainData.loc[:, 'petal length (cm)'].min() - .5  
maximum = trainData.loc[:, 'petal length (cm)'].max() + .5 

ax.set_ylim(-0.01,0.01)
ax.set_xlim(minimum,maximum)
xlist = np.linspace(minimum, maximum, 100)

# ylist could be anything in this case
ylist = np.linspace(-3.0, 3.0, 100)
xx, yy = np.meshgrid(xlist, ylist)

# Making an array of the same shape as input 
# This is an array to mimic a decision boundary 
Z = xx.copy()

# https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html
# my decision boundary 
def boundary(array):
    if array <= 3.6:
        return(0)
    if array > 3.6:
        return(2)
    else:
        return()

vfunc = np.vectorize(boundary)
Z = vfunc(Z)

# Put the result into a color plot 
n_classes = 2 

custom_map = mpl.colors.ListedColormap(['lime', 'cyan'])

contours = plt.contourf(xx, yy, Z, alpha=0.3,
                       cmap=custom_map,
                       zorder=1)

ax.axvline(x = 3.6, c = 'k')
ax.set_yticks([])
ax.set_yticklabels([])
#ax.set_xlabel('petal length (cm)', fontsize = 14)
ax.set_title('Is the petal length (cm) <= 3.6', fontsize = 17)


ax.annotate('Misclassified', xy=(3.515,-0.0005), xytext=(2.3,-0.006), fontsize = 13,
            arrowprops={'arrowstyle': '->', 'color': 'black', 'lw': 2},
            va='center');

ax.annotate('', xy=(3.3,-0.0005), xytext=(3.06,-0.0046), fontsize = 13,
            arrowprops={'arrowstyle': '->', 'color': 'black', 'lw': 2},
            va='center');

ax.annotate('', xy=(3.02,-0.0005), xytext=(3.06,-0.0049), fontsize = 13,
            arrowprops={'arrowstyle': '->', 'color': 'black', 'lw': 2},
            va='center');

plt.gcf().subplots_adjust(bottom=0.20)
plt.savefig('../dotfiles/notperfectClassDN1_bad_split.png', dpi = 800)

# %% [markdown]
# ## Visualizing Depth

# %% [markdown]
# ### Depth 1

# %%
Image(filename ="../images/iris_depth1_2f_color_decisionTree.png")

# %% [markdown]
# ### Depth 2

# %%
Image(filename ="../images/iris_depth2_2f_color_decisionTree.png")

# %% [markdown]
# ### Depth 3

# %%
Image(filename ="../images/iris_depth3_2f_color_decisionTree.png")
