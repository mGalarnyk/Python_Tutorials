# %% [markdown]
# Deep Learning
# =============
#
# Assignment 2
# ------------
#
# Previously in `1_notmnist.ipynb`, we created a pickle with formatted datasets for training, development and testing on the [notMNIST dataset](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html).
#
# The goal of this assignment is to progressively train deeper and more accurate models using TensorFlow.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
    dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
    # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %% [markdown]
# We're first going to train a multinomial logistic regression (sigmoid regression) using simple gradient descent.
#
# TensorFlow works like this:
# * First you describe the computation that you want to see performed: what the inputs, the variables, and the operations look like. These get created as nodes over a computation graph. This description is all contained within the block below:
#
#       with graph.as_default():
#           ...
#
# * Then you can run the operations on this graph as many times as you want by calling `session.run()`, providing it outputs to fetch from the graph that get returned. This runtime operation is all contained in the block below:
#
#       with tf.Session(graph=graph) as session:
#           ...
#
# Let's load all the data into TensorFlow and build the computation graph corresponding to our training:

# %%
-

# %% [markdown]
# Let's run this computation and iterate:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

V_accur_list = [] #verification accuracy list
step_list = [] # step number list
cost_list = []

# %%
num_steps = 801

def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1)) / predictions.shape[0])

with tf.Session(graph=graph) as session:
    # This is a one-time operation which ensures the parameters get initialized as
    # we described in the graph: random weights for the matrix, zeros for the
    # biases. 
    tf.initialize_all_variables().run()
    print('Initialized')
    for step in range(num_steps):
        # Run the computations. We tell .run() that we want to run the optimizer,
        # and get the loss value and the training predictions returned as numpy
        # arrays.
        _, l, predictions = session.run([optimizer, loss, train_prediction])
        if (step % 20 == 0):
            cost_list.append(l)
            step_list.append(step)
            print('Loss at step %d: %f' % (step, l))
            print('Training accuracy: %.1f%%' % accuracy(
            predictions, train_labels[:train_subset, :]))
            # Calling .eval() on valid_prediction is basically like calling run(), but
            # just to get that one numpy array. Note that it recomputes all its graph
            # dependencies.
            valid_accuracy = accuracy(valid_prediction.eval(), valid_labels)
            V_accur_list.append(valid_accuracy)
            print('Validation accuracy: %.1f%%' % valid_accuracy)
    test_accuracy = accuracy(test_prediction.eval(), test_labels)
    print('Test accuracy: %.1f%%' % test_accuracy)
    #This line below allows for taking the predictions to a pandas dataframe and eventually a heatmap/confusion matrix
    pred = test_prediction.eval()
# Out:
# Initialized
# Loss at step 0: 18.297424
# Training accuracy: 10.2%
# Validation accuracy: 13.3%
# Loss at step 20: 3.990589
# Training accuracy: 56.5%
# Validation accuracy: 57.9%
# Loss at step 40: 3.214879
# Training accuracy: 64.8%
# Validation accuracy: 65.0%
# Loss at step 60: 2.861358
# Training accuracy: 67.9%
# Validation accuracy: 68.0%
# Loss at step 80: 2.633859
# Training accuracy: 69.8%
# Validation accuracy: 69.7%
# Loss at step 100: 2.467070
# Training accuracy: 71.0%
# Validation accuracy: 70.8%
# Loss at step 120: 2.335478
# Training accuracy: 71.8%
# Validation accuracy: 71.4%
# Loss at step 140: 2.227185
# Training accuracy: 72.6%
# Validation accuracy: 71.9%
# Loss at step 160: 2.135313
# Training accuracy: 73.0%
# Validation accuracy: 72.2%
# Loss at step 180: 2.055514
# Training accuracy: 73.5%
# Validation accuracy: 72.5%
# Loss at step 200: 1.984977
# Training accuracy: 74.0%
# Validation accuracy: 72.7%
# Loss at step 220: 1.921830
# Training accuracy: 74.1%
# Validation accuracy: 72.9%
# Loss at step 240: 1.864768
# Training accuracy: 74.6%
# Validation accuracy: 73.1%
# Loss at step 260: 1.812810
# Training accuracy: 74.8%
# Validation accuracy: 73.2%
# Loss at step 280: 1.765169
# Training accuracy: 75.1%
# Validation accuracy: 73.2%
# Loss at step 300: 1.721196
# Training accuracy: 75.3%
# Validation accuracy: 73.4%
# Loss at step 320: 1.680373
# Training accuracy: 75.4%
# Validation accuracy: 73.4%
# Loss at step 340: 1.642283
# Training accuracy: 75.6%
# Validation accuracy: 73.5%
# Loss at step 360: 1.606596
# Training accuracy: 75.8%
# Validation accuracy: 73.6%
# Loss at step 380: 1.573047
# Training accuracy: 75.9%
# Validation accuracy: 73.7%
# Loss at step 400: 1.541422
# Training accuracy: 76.1%
# Validation accuracy: 73.8%
# Loss at step 420: 1.511543
# Training accuracy: 76.2%
# Validation accuracy: 73.9%
# Loss at step 440: 1.483259
# Training accuracy: 76.2%
# Validation accuracy: 73.8%
# Loss at step 460: 1.456430
# Training accuracy: 76.3%
# Validation accuracy: 73.8%
# Loss at step 480: 1.430941
# Training accuracy: 76.5%
# Validation accuracy: 73.8%
# Loss at step 500: 1.406685
# Training accuracy: 76.6%
# Validation accuracy: 73.8%
# Loss at step 520: 1.383564
# Training accuracy: 76.6%
# Validation accuracy: 74.0%
# Loss at step 540: 1.361495
# Training accuracy: 76.8%
# Validation accuracy: 74.0%
# Loss at step 560: 1.340400
# Training accuracy: 76.9%
# Validation accuracy: 74.0%
# Loss at step 580: 1.320211
# Training accuracy: 77.0%
# Validation accuracy: 74.1%
# Loss at step 600: 1.300868
# Training accuracy: 77.0%
# Validation accuracy: 74.1%
# Loss at step 620: 1.282312
# Training accuracy: 77.1%
# Validation accuracy: 74.2%
# Loss at step 640: 1.264493
# Training accuracy: 77.2%
# Validation accuracy: 74.2%
# Loss at step 660: 1.247364
# Training accuracy: 77.3%
# Validation accuracy: 74.3%
# Loss at step 680: 1.230884
# Training accuracy: 77.5%
# Validation accuracy: 74.3%
# Loss at step 700: 1.215011
# Training accuracy: 77.6%
# Validation accuracy: 74.4%
# Loss at step 720: 1.199710
# Training accuracy: 77.7%
# Validation accuracy: 74.5%
# Loss at step 740: 1.184950
# Training accuracy: 77.7%
# Validation accuracy: 74.5%
# Loss at step 760: 1.170698
# Training accuracy: 77.9%
# Validation accuracy: 74.5%
# Loss at step 780: 1.156927
# Training accuracy: 77.9%
# Validation accuracy: 74.5%
# Loss at step 800: 1.143609
# Training accuracy: 78.0%
# Validation accuracy: 74.5%
# Test accuracy: 82.5%

# %%
from sklearn import metrics
import pandas as pd
import seaborn as sns

fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (30,9));
fig.subplots_adjust(wspace=0.15, hspace=0) # Bringing subplots closer together. 
axes[0].plot(step_list, cost_list);
axes[0].set_figure
axes[0].set_title('Cost vs Steps', size = 20);
axes[0].set_xlabel('Steps', size = 17);
axes[0].set_ylabel('Cost', size = 17);
axes[1].plot(step_list, V_accur_list);
axes[1].set_title('Validation Accuracy vs Steps', size = 20);
axes[1].set_xlabel('Steps', size = 17);
axes[1].set_ylabel('Validation Accuracy', size = 17);

# predictions
predicted = [np.argmax(pred[i,:], 0) for i in xrange(0,pred.shape[0])]
#actual
t_labels = [np.where(test_labels[i] == 1)[0][0] for i in xrange(0,pred.shape[0])]

cm = metrics.confusion_matrix(t_labels, predicted)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
confusion_matrix = pd.DataFrame(data = cm_normalized)
sns.heatmap(confusion_matrix, annot=True, fmt=".3f", linewidths=.5, square = True,ax = axes[2], cmap = 'Blues_r', cbar = False);
axes[2].set_ylabel('Actual label', size = 17);
axes[2].set_xlabel('Predicted label', size = 17);
confusion_title = 'Confusion Matrix ({}%)'.format(test_accuracy)
axes[2].set_title(confusion_title, size = 20);
fig.suptitle('Multinomial Logistic Regression', y=1,x = .52, size = 40);

# %% [markdown]
# Let's now switch to stochastic gradient descent training instead, which is much faster.
#
# The graph will be similar, except that instead of holding all the training data into a constant node, we create a `Placeholder` node which will be fed actual data at every call of `session.run()`.

# %%
batch_size = 128

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
  
    # Variables.
    weights = tf.Variable(tf.truncated_normal([image_size * image_size, num_labels]))
    biases = tf.Variable(tf.zeros([num_labels]))
  
    # Training computation.
    logits = tf.matmul(tf_train_dataset, weights) + biases
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
  
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(tf.matmul(tf_valid_dataset, weights) + biases)
    test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %% [markdown]
# Let's run it:

# %%
num_steps = 5001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("Initialized")
    for step in range(num_steps):
        # Pick an offset within the training data, which has been randomized.
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        # Prepare a dictionary telling the session where to feed the minibatch.
        # The key of the dictionary is the placeholder node of the graph to be fed,
        # and the value is the numpy array to feed to it.
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 16.867481
# Minibatch accuracy: 12.5%
# Validation accuracy: 11.7%
# Minibatch loss at step 500: 2.498480
# Minibatch accuracy: 71.1%
# Validation accuracy: 75.6%
# Minibatch loss at step 1000: 1.369528
# Minibatch accuracy: 78.1%
# Validation accuracy: 76.5%
# Minibatch loss at step 1500: 1.381620
# Minibatch accuracy: 73.4%
# Validation accuracy: 77.9%
# Minibatch loss at step 2000: 1.253939
# Minibatch accuracy: 82.0%
# Validation accuracy: 76.8%
# Minibatch loss at step 2500: 1.100941
# Minibatch accuracy: 73.4%
# Validation accuracy: 78.2%
# Minibatch loss at step 3000: 0.973045
# Minibatch accuracy: 76.6%
# Validation accuracy: 78.3%
# Minibatch loss at step 3500: 0.644432
# Minibatch accuracy: 85.2%
# Validation accuracy: 78.6%
# Minibatch loss at step 4000: 0.969978
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.7%
# Minibatch loss at step 4500: 0.669738
# Minibatch accuracy: 82.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 5000: 0.596673
# Minibatch accuracy: 83.6%
# Validation accuracy: 79.7%
# Test accuracy: 87.4%

# %% [markdown]
# ---
# Problem
# -------
#
# Turn the logistic regression example with SGD into a 1-hidden layer neural network with rectified linear units [nn.relu()](https://www.tensorflow.org/versions/r0.7/api_docs/python/nn.html#relu) and 1024 hidden nodes. This model should improve your validation / test accuracy.
#
# ---

# %%
V_accur_list, step_list, cost_list = [], [], []

# %%
# Setting up the Computation graph always comes first

batch_size = 128
n_hidden_nodes = 1024
image_size = 28

graph = tf.Graph()
with graph.as_default():
    
    # Input data. For the training data, we use a placeholder that will be 
    # fed at runtime with a training minibatch
    tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Variables.
    weights_01 = tf.Variable(
    tf.truncated_normal([image_size * image_size, n_hidden_nodes]))
    weights_12 = tf.Variable(tf.truncated_normal([n_hidden_nodes, num_labels]))
    biases_01 = tf.Variable(tf.zeros([n_hidden_nodes]))
    biases_12 = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    z_01= tf.matmul(tf_train_dataset, weights_01) + biases_01
    h1 = tf.nn.relu(z_01)
    z_12 = tf.matmul(h1, weights_12) + biases_12
    loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(z_12, tf_train_labels))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(z_12)
    valid_prediction = tf.nn.softmax(
    tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, weights_01) + biases_01), weights_12) + biases_12)
    test_prediction = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset, weights_01) + biases_01), weights_12) + biases_12)

# %%
num_steps = 12001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("Initialized")
    for step in range(num_steps):
        # Pick an offset within the training data, which has been randomized.
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        # Prepare a dictionary telling the session where to feed the minibatch.
        # The key of the dictionary is the placeholder node of the graph to be fed,
        # and the value is the numpy array to feed to it.
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 100 == 0):
            cost_list.append(l)
            step_list.append(step)
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            valid_accuracy = accuracy(valid_prediction.eval(), valid_labels)
            V_accur_list.append(valid_accuracy)
            print("Validation accuracy: %.1f%%" % valid_accuracy)
    test_accuracy = accuracy(test_prediction.eval(), test_labels)
    print('Test accuracy: %.1f%%' % test_accuracy)
    #This line below allows for taking the predictions to a pandas dataframe and eventually a heatmap/confusion matrix
    pred = test_prediction.eval()
# Out:
# Initialized
# Minibatch loss at step 0: 469.329346
# Minibatch accuracy: 9.4%
# Validation accuracy: 35.7%
# Minibatch loss at step 100: 46.192879
# Minibatch accuracy: 77.3%
# Validation accuracy: 76.5%
# Minibatch loss at step 200: 42.081703
# Minibatch accuracy: 71.9%
# Validation accuracy: 79.2%
# Minibatch loss at step 300: 19.856094
# Minibatch accuracy: 80.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 400: 15.045023
# Minibatch accuracy: 82.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 500: 17.407333
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.1%
# Minibatch loss at step 600: 6.122468
# Minibatch accuracy: 89.1%
# Validation accuracy: 81.8%
# Minibatch loss at step 700: 6.940934
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.8%
# Minibatch loss at step 800: 6.072328
# Minibatch accuracy: 85.9%
# Validation accuracy: 80.9%
# Minibatch loss at step 900: 11.265715
# Minibatch accuracy: 77.3%
# Validation accuracy: 81.0%
# Minibatch loss at step 1000: 8.393486
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 1100: 9.054470
# Minibatch accuracy: 77.3%
# Validation accuracy: 79.8%
# Minibatch loss at step 1200: 3.601852
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.4%
# Minibatch loss at step 1300: 9.658389
# Minibatch accuracy: 84.4%
# Validation accuracy: 79.9%
# Minibatch loss at step 1400: 7.466922
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.4%
# Minibatch loss at step 1500: 10.323712
# Minibatch accuracy: 74.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 1600: 4.043959
# Minibatch accuracy: 78.9%
# Validation accuracy: 80.5%
# Minibatch loss at step 1700: 2.703983
# Minibatch accuracy: 86.7%
# Validation accuracy: 82.5%
# Minibatch loss at step 1800: 4.828417
# Minibatch accuracy: 79.7%
# Validation accuracy: 79.6%
# Minibatch loss at step 1900: 7.124076
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.9%
# Minibatch loss at step 2000: 5.520388
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 2100: 5.850259
# Minibatch accuracy: 85.9%
# Validation accuracy: 81.5%
# Minibatch loss at step 2200: 14.300352
# Minibatch accuracy: 82.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 2300: 4.579258
# Minibatch accuracy: 79.7%
# Validation accuracy: 82.2%
# Minibatch loss at step 2400: 5.191687
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.2%
# Minibatch loss at step 2500: 9.360111
# Minibatch accuracy: 75.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 2600: 5.291294
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 2700: 1.953277
# Minibatch accuracy: 85.9%
# Validation accuracy: 81.3%
# Minibatch loss at step 2800: 4.959462
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.8%
# Minibatch loss at step 2900: 9.110456
# Minibatch accuracy: 82.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 3000: 2.383710
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.8%
# Minibatch loss at step 3100: 4.242324
# Minibatch accuracy: 78.9%
# Validation accuracy: 82.4%
# Minibatch loss at step 3200: 2.386684
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.2%
# Minibatch loss at step 3300: 1.642406
# Minibatch accuracy: 85.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 3400: 5.279343
# Minibatch accuracy: 82.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 3500: 3.233987
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 3600: 1.053617
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.0%
# Minibatch loss at step 3700: 3.526180
# Minibatch accuracy: 85.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 3800: 2.318745
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.1%
# Minibatch loss at step 3900: 2.823146
# Minibatch accuracy: 85.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 4000: 1.552991
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 4100: 2.595619
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.5%
# Minibatch loss at step 4200: 1.996096
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.6%
# Minibatch loss at step 4300: 6.847262
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.3%
# Minibatch loss at step 4400: 2.040215
# Minibatch accuracy: 85.9%
# Validation accuracy: 81.9%
# Minibatch loss at step 4500: 0.596704
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.8%
# Minibatch loss at step 4600: 5.642856
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.1%
# Minibatch loss at step 4700: 1.860522
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.1%
# Minibatch loss at step 4800: 2.552052
# Minibatch accuracy: 89.1%
# Validation accuracy: 83.0%
# Minibatch loss at step 4900: 1.832598
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.6%
# Minibatch loss at step 5000: 1.216268
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 5100: 1.530303
# Minibatch accuracy: 85.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 5200: 1.907367
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.9%
# Minibatch loss at step 5300: 1.299325
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.3%
# Minibatch loss at step 5400: 1.450319
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 5500: 2.424646
# Minibatch accuracy: 80.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 5600: 2.588694
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.9%
# Minibatch loss at step 5700: 2.853811
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.2%
# Minibatch loss at step 5800: 3.716126
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 5900: 1.645213
# Minibatch accuracy: 89.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 6000: 2.312813
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.7%
# Minibatch loss at step 6100: 1.036187
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.5%
# Minibatch loss at step 6200: 4.938224
# Minibatch accuracy: 78.9%
# Validation accuracy: 83.4%
# Minibatch loss at step 6300: 1.515348
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.3%
# Minibatch loss at step 6400: 1.031105
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.1%
# Minibatch loss at step 6500: 2.947537
# Minibatch accuracy: 77.3%
# Validation accuracy: 83.1%
# Minibatch loss at step 6600: 2.047115
# Minibatch accuracy: 82.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 6700: 2.897274
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.8%
# Minibatch loss at step 6800: 1.952135
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.8%
# Minibatch loss at step 6900: 1.002066
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 7000: 1.781143
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.2%
# Minibatch loss at step 7100: 2.417555
# Minibatch accuracy: 82.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 7200: 3.077065
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.0%
# Minibatch loss at step 7300: 4.680845
# Minibatch accuracy: 89.1%
# Validation accuracy: 83.6%
# Minibatch loss at step 7400: 1.633122
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 7500: 1.781804
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 7600: 0.729576
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.7%
# Minibatch loss at step 7700: 0.952895
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.6%
# Minibatch loss at step 7800: 2.034279
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.3%
# Minibatch loss at step 7900: 1.576024
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.7%
# Minibatch loss at step 8000: 0.767727
# Minibatch accuracy: 89.1%
# Validation accuracy: 82.9%
# Minibatch loss at step 8100: 2.717551
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.8%
# Minibatch loss at step 8200: 0.365921
# Minibatch accuracy: 93.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 8300: 0.493212
# Minibatch accuracy: 93.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 8400: 0.474444
# Minibatch accuracy: 91.4%
# Validation accuracy: 83.8%
# Minibatch loss at step 8500: 0.659612
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.1%
# Minibatch loss at step 8600: 1.223030
# Minibatch accuracy: 91.4%
# Validation accuracy: 84.2%
# Minibatch loss at step 8700: 0.603350
# Minibatch accuracy: 92.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 8800: 0.805609
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.9%
# Minibatch loss at step 8900: 0.844447
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 9000: 1.508975
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.6%
# Minibatch loss at step 9100: 0.647478
# Minibatch accuracy: 89.1%
# Validation accuracy: 83.8%
# Minibatch loss at step 9200: 0.965345
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.6%
# Minibatch loss at step 9300: 1.490952
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.9%
# Minibatch loss at step 9400: 0.960798
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.9%
# Minibatch loss at step 9500: 0.962706
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 9600: 0.996999
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.0%
# Minibatch loss at step 9700: 1.731219
# Minibatch accuracy: 86.7%
# Validation accuracy: 84.4%
# Minibatch loss at step 9800: 0.852020
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.2%
# Minibatch loss at step 9900: 1.232600
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 10000: 1.288924
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.0%
# Minibatch loss at step 10100: 0.501099
# Minibatch accuracy: 91.4%
# Validation accuracy: 84.7%
# Minibatch loss at step 10200: 1.312578
# Minibatch accuracy: 92.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 10300: 0.777592
# Minibatch accuracy: 89.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 10400: 2.880570
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 10500: 1.718604
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.3%
# Minibatch loss at step 10600: 0.725505
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.6%
# Minibatch loss at step 10700: 0.783942
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.6%
# Minibatch loss at step 10800: 1.180291
# Minibatch accuracy: 88.3%
# Validation accuracy: 84.2%
# Minibatch loss at step 10900: 0.978870
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.3%
# Minibatch loss at step 11000: 0.763528
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.2%
# Minibatch loss at step 11100: 1.172673
# Minibatch accuracy: 83.6%
# Validation accuracy: 84.3%
# Minibatch loss at step 11200: 0.710936
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.2%
# Minibatch loss at step 11300: 0.739686
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.8%
# Minibatch loss at step 11400: 0.661250
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.4%
# Minibatch loss at step 11500: 0.825785
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 11600: 0.817053
# Minibatch accuracy: 88.3%
# Validation accuracy: 84.8%
# Minibatch loss at step 11700: 0.760459
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.9%
# Minibatch loss at step 11800: 1.099307
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 11900: 3.016211
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.9%
# Minibatch loss at step 12000: 2.136934
# Minibatch accuracy: 88.3%
# Validation accuracy: 84.5%
# Test accuracy: 91.1%

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (30,9));
fig.subplots_adjust(wspace=0.15, hspace=0) # Bringing subplots closer together. 
axes[0].plot(step_list, cost_list);
axes[0].set_figure
axes[0].set_title('Cost vs Steps', size = 20);
axes[0].set_xlabel('Steps', size = 17);
axes[0].set_ylabel('Cost', size = 17);
axes[1].plot(step_list, V_accur_list);
axes[1].set_title('Validation Accuracy vs Steps', size = 20);
axes[1].set_xlabel('Steps', size = 17);
axes[1].set_ylabel('Validation Accuracy', size = 17);

# predictions
predicted = [np.argmax(pred[i,:], 0) for i in xrange(0,pred.shape[0])]
#actual
t_labels = [np.where(test_labels[i] == 1)[0][0] for i in xrange(0,pred.shape[0])]

cm = metrics.confusion_matrix(t_labels, predicted)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
confusion_matrix = pd.DataFrame(data = cm_normalized)
sns.heatmap(confusion_matrix, annot=True, fmt=".3f", linewidths=.5, square = True,ax = axes[2], cmap = 'Blues_r', cbar = False);
axes[2].set_ylabel('Actual label', size = 17);
axes[2].set_xlabel('Predicted label', size = 17);
confusion_title = 'Confusion Matrix ({}%)'.format(test_accuracy)
axes[2].set_title(confusion_title, size = 20);
fig.suptitle('1-Hidden Layer Neural Network', y=1,x = .52, size = 40);
